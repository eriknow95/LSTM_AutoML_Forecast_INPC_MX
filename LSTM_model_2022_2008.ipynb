# %%
import numpy as np
np.random.seed(4)
import matplotlib.pyplot as plt
from matplotlib import pylab, mlab, pyplot
from IPython.display import display
from IPython.core.pylabtools import figsize, getfigs
from pylab import *
import pandas as pd
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.patches as mpatches
from scipy.stats import randint
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Dropout
#Todos los títulos en times new roman
plt.rc('font', family='Times New Roman')
#
# Funciones auxiliares
#
def graficar_predicciones(real, prediccion):
    plt.plot(real[0:len(prediccion)],color='red', label='INPC Real')
    plt.plot(prediccion, color='blue', label='Predicción INPC')
    plt.ylim(1.1 * np.min(prediccion)/2, 1.1 * np.max(prediccion))
    plt.xlabel('Año')
    plt.ylabel('Nivel')
    plt.title('Rendimiento del modelo')
    plt.legend()
    plt.show()

# %%
#
# Lectura de los datos
#
dataset = pd.read_excel('IPC_LSTM.xlsx',sheet_name='sample', index_col='Date', parse_dates=['Date'])
dataset=dataset.resample('M').last()
dataset.head()
# Out:
#                 INPC
# Date
# 1969-01-31  0.011595
# 1969-02-28  0.011636
# 1969-03-31  0.011648
# 1969-04-30  0.011680
# 1969-05-31  0.011680

# %%
#Veamos la descripción de los datos
descripcion1=pd.DataFrame(dataset.describe())
descripcion1
descripcion1.to_csv('descripciondatos.csv')

# %%
descripcion1=pd.DataFrame(dataset.describe())
descripcion1
# Out:
#              INPC
# count  651.000000
# mean    38.007879
# std     39.048666
# min      0.011595
# 25%      0.119887
# 50%     23.874262
# 75%     70.715800
# max    128.389000

# %%
#Visualizamos los datos
TN= 'Times New Roman'
plt.figure()
plt.plot(dataset)
plt.ylabel('Nivel', fontname=TN)
plt.xlabel('Áño', fontname=TN)
plt.title('INPC (1989-2023)', fontname=TN)
for i in plt.get_fignums():
    plt.figure(i)
    plt.savefig('figure%d.png' % i)
plt.show()

# %%
#Promedio mensual
dataset['INPC'].resample('M').mean().plot(kind='bar')
plt.xticks(rotation=60)
plt.ylabel('Nivel', fontname=TN)
plt.title('INPC (promedio mensual)', fontname=TN)
plt.show()
#Visualizamos la suma y el promedio
dataset.INPC.resample('M').sum().plot()
plt.ylabel('Nivel', fontname=TN)
plt.xlabel('Áño', fontname=TN)
plt.title('INPC (suma mensual)', fontname=TN)
plt.tight_layout()
plt.show()
dataset.INPC.resample('M').mean().plot(color='red') 
plt.ylabel('Nivel', fontname=TN)
plt.xlabel('Áño', fontname=TN)
plt.title('INPC (promedio mensual)', fontname=TN)
plt.tight_layout()
plt.show()

# %%
# Sets de entrenamiento y validación 
# La LSTM se entrenará con datos de 1969-2012. La validación se hará con datos de 2013-2022.
# En ambos casos sólo se usará el valor más alto de la acción para cada día
#
set_entrenamiento = dataset[:'2012']
set_validacion = dataset['2013':]
#Visualizamos la partición
plt.figure(figsize=(10, 5))
Entrenamiento = mpatches.Patch(color='blue', label='Entrenamiento (1969-2012)')
Prueba = mpatches.Patch(color='gold', label='Validación (2013-2022)')
set_entrenamiento.resample('Y').plot(color='blue')
set_validacion.resample('Y').plot(color='gold')
plt.legend(handles=[Entrenamiento,Prueba],loc='best')
plt.ylabel('INPC', fontname=TN)
plt.xlabel('Años', fontname=TN)
plt.title('Partición de la base de datos', fontname=TN)
plt.show()

# %%
# Normalización del set de entrenamiento
sc = MinMaxScaler(feature_range=(0,1))
set_entrenamiento_escalado = sc.fit_transform(set_entrenamiento)

# La red LSTM tendrá como entrada "time_step" datos consecutivos, y como salida 1 dato (la predicción a
# partir de esos "time_step" datos). Se conformará de esta forma el set de entrenamiento
time_step = 3
X_train = []
Y_train = []
m = len(set_entrenamiento_escalado)

for i in range(time_step,m):
    # X: bloques de "time_step" datos: 0-time_step, 1-time_step+1, 2-time_step+2, etc
    X_train.append(set_entrenamiento_escalado[i-time_step:i,0])

    # Y: el siguiente dato
    Y_train.append(set_entrenamiento_escalado[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Reshape X_train para que se ajuste al modelo en Keras
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
#Ahora vamos a darle forma al set de prueba
set_validacion_escalado = sc.fit_transform(set_validacion)
m = len(set_validacion_escalado)
x_test = []
y_test = []
for i in range(time_step,m):
    # X: bloques de "time_step" datos: 0-time_step, 1-time_step+1, 2-time_step+2, etc
    x_test.append(set_validacion_escalado[i-time_step:i,0])

    # Y: el siguiente dato
    y_test.append(set_validacion_escalado[i,0])
x_test, y_test = np.array(x_test), np.array(y_test)

# Reshape x_test para que se ajuste al modelo en Keras
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
#
# Red LSTM
#
dim_entrada = (X_train.shape[1],1)
dim_salida = 1
na = 100

modelo = Sequential()
modelo.add(LSTM(units=na, input_shape=dim_entrada, return_sequences=True))
modelo.add(LSTM(units=20, input_shape=dim_entrada, return_sequences=False))
modelo.add(Dropout(0.1))
modelo.add(Dense(units=dim_salida))
modelo.compile(optimizer='adam', loss='mse')
hist = modelo.fit(X_train, Y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test), verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 17/17 - 4s - loss: 0.1529 - val_loss: 0.1363 - 4s/epoch - 218ms/step
# Epoch 2/100
# 17/17 - 0s - loss: 0.0591 - val_loss: 0.0385 - 125ms/epoch - 7ms/step
# Epoch 3/100
# 17/17 - 0s - loss: 0.0234 - val_loss: 0.0109 - 94ms/epoch - 6ms/step
# Epoch 4/100
# 17/17 - 0s - loss: 0.0213 - val_loss: 0.0026 - 94ms/epoch - 6ms/step
# Epoch 5/100
# 17/17 - 0s - loss: 0.0061 - val_loss: 0.0018 - 110ms/epoch - 6ms/step
# Epoch 6/100
# 17/17 - 0s - loss: 0.0039 - val_loss: 0.0025 - 110ms/epoch - 6ms/step
# Epoch 7/100
# 17/17 - 0s - loss: 0.0100 - val_loss: 0.0025 - 94ms/epoch - 6ms/step
# Epoch 8/100
# 17/17 - 0s - loss: 0.0102 - val_loss: 0.0025 - 97ms/epoch - 6ms/step
# Epoch 9/100
# 17/17 - 0s - loss: 0.0314 - val_loss: 0.0190 - 91ms/epoch - 5ms/step
# Epoch 10/100
# 17/17 - 0s - loss: 0.0063 - val_loss: 3.8072e-04 - 110ms/epoch - 6ms/step
# Epoch 11/100
# 17/17 - 0s - loss: 0.0060 - val_loss: 0.0036 - 94ms/epoch - 6ms/step
# Epoch 12/100
# 17/17 - 0s - loss: 0.0034 - val_loss: 3.8723e-04 - 100ms/epoch - 6ms/step
# Epoch 13/100
# 17/17 - 0s - loss: 0.0043 - val_loss: 0.0019 - 100ms/epoch - 6ms/step
# Epoch 14/100
# 17/17 - 0s - loss: 0.0037 - val_loss: 4.9356e-04 - 107ms/epoch - 6ms/step
# Epoch 15/100
# 17/17 - 0s - loss: 0.0045 - val_loss: 0.0021 - 94ms/epoch - 6ms/step
# Epoch 16/100
# 17/17 - 0s - loss: 0.0038 - val_loss: 7.8552e-04 - 99ms/epoch - 6ms/step
# Epoch 17/100
# 17/17 - 0s - loss: 0.0071 - val_loss: 0.0022 - 105ms/epoch - 6ms/step
# Epoch 18/100
# 17/17 - 0s - loss: 0.0070 - val_loss: 8.5824e-04 - 96ms/epoch - 6ms/step
# Epoch 19/100
# 17/17 - 0s - loss: 0.0138 - val_loss: 0.0065 - 108ms/epoch - 6ms/step
# Epoch 20/100
# 17/17 - 0s - loss: 0.0067 - val_loss: 1.9792e-04 - 94ms/epoch - 6ms/step
# Epoch 21/100
# 17/17 - 0s - loss: 0.0068 - val_loss: 0.0034 - 98ms/epoch - 6ms/step
# Epoch 22/100
# 17/17 - 0s - loss: 0.0041 - val_loss: 3.3197e-04 - 106ms/epoch - 6ms/step
# Epoch 23/100
# 17/17 - 0s - loss: 0.0039 - val_loss: 0.0019 - 95ms/epoch - 6ms/step
# Epoch 24/100
# 17/17 - 0s - loss: 0.0033 - val_loss: 3.6758e-04 - 100ms/epoch - 6ms/step
# Epoch 25/100
# 17/17 - 0s - loss: 0.0042 - val_loss: 0.0016 - 100ms/epoch - 6ms/step
# Epoch 26/100
# 17/17 - 0s - loss: 0.0043 - val_loss: 5.7006e-04 - 97ms/epoch - 6ms/step
# Epoch 27/100
# 17/17 - 0s - loss: 0.0050 - val_loss: 0.0021 - 107ms/epoch - 6ms/step
# Epoch 28/100
# 17/17 - 0s - loss: 0.0037 - val_loss: 3.8882e-04 - 109ms/epoch - 6ms/step
# Epoch 29/100
# 17/17 - 0s - loss: 0.0038 - val_loss: 0.0016 - 94ms/epoch - 6ms/step
# Epoch 30/100
# 17/17 - 0s - loss: 0.0030 - val_loss: 4.4923e-04 - 110ms/epoch - 6ms/step
# Epoch 31/100
# 17/17 - 0s - loss: 0.0034 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 32/100
# 17/17 - 0s - loss: 0.0034 - val_loss: 5.0551e-04 - 94ms/epoch - 6ms/step
# Epoch 33/100
# 17/17 - 0s - loss: 0.0047 - val_loss: 0.0017 - 94ms/epoch - 6ms/step
# Epoch 34/100
# 17/17 - 0s - loss: 0.0040 - val_loss: 6.2489e-04 - 99ms/epoch - 6ms/step
# Epoch 35/100
# 17/17 - 0s - loss: 0.0051 - val_loss: 0.0015 - 89ms/epoch - 5ms/step
# Epoch 36/100
# 17/17 - 0s - loss: 0.0046 - val_loss: 5.4839e-04 - 83ms/epoch - 5ms/step
# Epoch 37/100
# 17/17 - 0s - loss: 0.0051 - val_loss: 0.0014 - 94ms/epoch - 6ms/step
# Epoch 38/100
# 17/17 - 0s - loss: 0.0044 - val_loss: 5.9651e-04 - 94ms/epoch - 6ms/step
# Epoch 39/100
# 17/17 - 0s - loss: 0.0039 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 40/100
# 17/17 - 0s - loss: 0.0033 - val_loss: 5.1747e-04 - 110ms/epoch - 6ms/step
# Epoch 41/100
# 17/17 - 0s - loss: 0.0034 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 42/100
# 17/17 - 0s - loss: 0.0031 - val_loss: 4.8427e-04 - 94ms/epoch - 6ms/step
# Epoch 43/100
# 17/17 - 0s - loss: 0.0032 - val_loss: 9.0207e-04 - 94ms/epoch - 6ms/step
# Epoch 44/100
# 17/17 - 0s - loss: 0.0039 - val_loss: 7.7317e-04 - 110ms/epoch - 6ms/step
# Epoch 45/100
# 17/17 - 0s - loss: 0.0044 - val_loss: 0.0010 - 94ms/epoch - 6ms/step
# Epoch 46/100
# 17/17 - 0s - loss: 0.0043 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 47/100
# 17/17 - 0s - loss: 0.0081 - val_loss: 0.0020 - 94ms/epoch - 6ms/step
# Epoch 48/100
# 17/17 - 0s - loss: 0.0064 - val_loss: 7.8180e-04 - 94ms/epoch - 6ms/step
# Epoch 49/100
# 17/17 - 0s - loss: 0.0082 - val_loss: 0.0022 - 94ms/epoch - 6ms/step
# Epoch 50/100
# 17/17 - 0s - loss: 0.0062 - val_loss: 5.4336e-04 - 110ms/epoch - 6ms/step
# Epoch 51/100
# 17/17 - 0s - loss: 0.0068 - val_loss: 0.0017 - 94ms/epoch - 6ms/step
# Epoch 52/100
# 17/17 - 0s - loss: 0.0056 - val_loss: 5.3585e-04 - 94ms/epoch - 6ms/step
# Epoch 53/100
# 17/17 - 0s - loss: 0.0045 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 54/100
# 17/17 - 0s - loss: 0.0041 - val_loss: 4.6766e-04 - 94ms/epoch - 6ms/step
# Epoch 55/100
# 17/17 - 0s - loss: 0.0046 - val_loss: 0.0016 - 94ms/epoch - 6ms/step
# Epoch 56/100
# 17/17 - 0s - loss: 0.0043 - val_loss: 5.4040e-04 - 110ms/epoch - 6ms/step
# Epoch 57/100
# 17/17 - 0s - loss: 0.0038 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 58/100
# 17/17 - 0s - loss: 0.0035 - val_loss: 4.9748e-04 - 94ms/epoch - 6ms/step
# Epoch 59/100
# 17/17 - 0s - loss: 0.0037 - val_loss: 0.0015 - 110ms/epoch - 6ms/step
# Epoch 60/100
# 17/17 - 0s - loss: 0.0029 - val_loss: 4.8915e-04 - 94ms/epoch - 6ms/step
# Epoch 61/100
# 17/17 - 0s - loss: 0.0028 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 62/100
# 17/17 - 0s - loss: 0.0031 - val_loss: 6.4549e-04 - 110ms/epoch - 6ms/step
# Epoch 63/100
# 17/17 - 0s - loss: 0.0037 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 64/100
# 17/17 - 0s - loss: 0.0036 - val_loss: 6.1635e-04 - 94ms/epoch - 6ms/step
# Epoch 65/100
# 17/17 - 0s - loss: 0.0033 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 66/100
# 17/17 - 0s - loss: 0.0031 - val_loss: 4.2630e-04 - 110ms/epoch - 6ms/step
# Epoch 67/100
# 17/17 - 0s - loss: 0.0023 - val_loss: 8.5622e-04 - 94ms/epoch - 6ms/step
# Epoch 68/100
# 17/17 - 0s - loss: 0.0026 - val_loss: 4.8342e-04 - 94ms/epoch - 6ms/step
# Epoch 69/100
# 17/17 - 0s - loss: 0.0030 - val_loss: 9.9879e-04 - 94ms/epoch - 6ms/step
# Epoch 70/100
# 17/17 - 0s - loss: 0.0021 - val_loss: 5.6804e-04 - 94ms/epoch - 6ms/step
# Epoch 71/100
# 17/17 - 0s - loss: 0.0023 - val_loss: 8.1879e-04 - 110ms/epoch - 6ms/step
# Epoch 72/100
# 17/17 - 0s - loss: 0.0027 - val_loss: 5.3982e-04 - 94ms/epoch - 6ms/step
# Epoch 73/100
# 17/17 - 0s - loss: 0.0025 - val_loss: 5.4235e-04 - 96ms/epoch - 6ms/step
# Epoch 74/100
# 17/17 - 0s - loss: 0.0023 - val_loss: 4.9410e-04 - 100ms/epoch - 6ms/step
# Epoch 75/100
# 17/17 - 0s - loss: 0.0014 - val_loss: 5.9078e-04 - 102ms/epoch - 6ms/step
# Epoch 76/100
# 17/17 - 0s - loss: 0.0018 - val_loss: 5.9279e-04 - 94ms/epoch - 6ms/step
# Epoch 77/100
# 17/17 - 0s - loss: 0.0017 - val_loss: 5.1461e-04 - 94ms/epoch - 6ms/step
# Epoch 78/100
# 17/17 - 0s - loss: 0.0019 - val_loss: 5.1952e-04 - 94ms/epoch - 6ms/step
# Epoch 79/100
# 17/17 - 0s - loss: 0.0015 - val_loss: 6.1226e-04 - 94ms/epoch - 6ms/step
# Epoch 80/100
# 17/17 - 0s - loss: 0.0020 - val_loss: 4.8910e-04 - 110ms/epoch - 6ms/step
# Epoch 81/100
# 17/17 - 0s - loss: 0.0015 - val_loss: 4.8740e-04 - 113ms/epoch - 7ms/step
# Epoch 82/100
# 17/17 - 0s - loss: 0.0012 - val_loss: 6.3195e-04 - 107ms/epoch - 6ms/step
# Epoch 83/100
# 17/17 - 0s - loss: 0.0012 - val_loss: 4.4857e-04 - 109ms/epoch - 6ms/step
# Epoch 84/100
# 17/17 - 0s - loss: 0.0025 - val_loss: 9.5292e-04 - 94ms/epoch - 6ms/step
# Epoch 85/100
# 17/17 - 0s - loss: 0.0030 - val_loss: 5.5801e-04 - 94ms/epoch - 6ms/step
# Epoch 86/100
# 17/17 - 0s - loss: 0.0045 - val_loss: 0.0020 - 97ms/epoch - 6ms/step
# Epoch 87/100
# 17/17 - 0s - loss: 0.0069 - val_loss: 0.0015 - 91ms/epoch - 5ms/step
# Epoch 88/100
# 17/17 - 0s - loss: 0.0074 - val_loss: 0.0024 - 85ms/epoch - 5ms/step
# Epoch 89/100
# 17/17 - 0s - loss: 0.0104 - val_loss: 0.0022 - 99ms/epoch - 6ms/step
# Epoch 90/100
# 17/17 - 0s - loss: 0.0086 - val_loss: 0.0022 - 89ms/epoch - 5ms/step
# Epoch 91/100
# 17/17 - 0s - loss: 0.0134 - val_loss: 0.0043 - 83ms/epoch - 5ms/step
# Epoch 92/100
# 17/17 - 0s - loss: 0.0080 - val_loss: 5.7415e-04 - 94ms/epoch - 6ms/step
# Epoch 93/100
# 17/17 - 0s - loss: 0.0084 - val_loss: 0.0026 - 94ms/epoch - 6ms/step
# Epoch 94/100
# 17/17 - 0s - loss: 0.0054 - val_loss: 5.4767e-04 - 94ms/epoch - 6ms/step
# Epoch 95/100
# 17/17 - 0s - loss: 0.0050 - val_loss: 0.0016 - 94ms/epoch - 6ms/step
# Epoch 96/100
# 17/17 - 0s - loss: 0.0041 - val_loss: 6.1561e-04 - 94ms/epoch - 6ms/step
# Epoch 97/100
# 17/17 - 0s - loss: 0.0047 - val_loss: 0.0021 - 94ms/epoch - 6ms/step
# Epoch 98/100
# 17/17 - 0s - loss: 0.0034 - val_loss: 4.2640e-04 - 125ms/epoch - 7ms/step
# Epoch 99/100
# 17/17 - 0s - loss: 0.0035 - val_loss: 0.0015 - 110ms/epoch - 6ms/step
# Epoch 100/100
# 17/17 - 0s - loss: 0.0027 - val_loss: 4.3727e-04 - 110ms/epoch - 6ms/step

# %%
#Visualizar la perdida en función de los epochs
plt.figure(figsize=(10, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Calibración del modelo')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['Entrenamiento', 'Prueba'], loc='upper right')
plt.show()

# %%
#Predicción de 2022
prediccion = modelo.predict(x_test)
prediccion = sc.inverse_transform(prediccion)
prediction = np.concatenate(prediccion, axis=0 ).tolist()
prediction = [item for sublist in prediccion for item in sublist]
prediction = pd.DataFrame(prediction)
rng = pd.date_range('2013-01-01 00:00:00', periods=123, freq='M')
rng = pd.DataFrame(rng)
prediction = pd.merge(rng, prediction, left_index=True, right_index=True, how='outer')
prediction.set_index('0_x')
prediction.columns = ['Date', 'INPC']
prediction.set_index(['Date'], inplace=True)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
footer_text = "Fuente: elaboración propia con datos del SIE Banxico."

plt.figure(figsize=(10, 5))

item_id = "INPC"
y_past = dataset[item_id]
y_pred = prediction[item_id]['2022':]
y_test = set_validacion[item_id]['2022-01':'2022-12']

plt.plot(y_past['2020-10':'2021'], label="Valores pasados")
plt.plot(y_pred, label="Predicción")
plt.plot(y_test, label="Valores futuros")
plt.title('INPC General / Predicción 2022/ Modelo LSTM')
plt.figtext(0.1, 0, footer_text, ha="left", va="bottom")

plt.legend();

# %%
footer_text = "Fuente: elaboración propia con datos del SIE Banxico."

plt.figure(figsize=(10, 5))

item_id = "INPC"
y_past = dataset[item_id]
y_pred = prediction[item_id]['2022':]
y_test = set_validacion[item_id]['2022-01':'2022-12']

plt.plot(y_past['2020-10':'2021'], label="Valores pasados")
plt.plot(y_pred, label="Predicción")
plt.plot(y_test, label="Valores futuros")
plt.title('INPC General / Predicción 2022/ Modelo LSTM')
plt.figtext(0.1, 0, footer_text, ha="left", va="bottom")

plt.legend();

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, prediction['2022-01':'2022-12'])
print('El MSE de la predicción es:', mse)
# Out:
# El MSE de la predicción es: 1.3376820088280006

# %%
#Pronóstico de 2008
df=dataset['2008-01':'2009-03']
x_total = df.values
x_total=sc.transform(x_total)
X_total= []
for i in range(time_step,len(x_total)):
    X_total.append(x_total[i-time_step:i,0])
X_total = np.array(X_total)
X_total = np.reshape(X_total, (X_total.shape[0],X_total.shape[1],1))
# Out:
# C:\Users\Erik Rosas\anaconda3\envs\ag\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
prediccion2= modelo.predict(X_total)
prediccion2 = sc.inverse_transform(prediccion2)
prediction2 = np.concatenate(prediccion2, axis=0 ).tolist()
prediction2 = [item for sublist in prediccion2 for item in sublist]
prediction2 = pd.DataFrame(prediction2)
rng = pd.date_range('2008-01-01 00:00:00', periods=12, freq='M')
rng = pd.DataFrame(rng)
prediction2 = pd.merge(rng, prediction2, left_index=True, right_index=True, how='outer')
prediction2.set_index('0_x')
prediction2.columns = ['Date', 'INPC']
prediction2.set_index(['Date'], inplace=True)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
#graficamos el pronóstico de 2008
plt.figure(figsize=(10, 5))

item_id = "INPC"
y_past = dataset[item_id]['2007-10':'2008-1']
y_pred = prediction2[item_id]['2008':]
y_test = df[item_id]['2008-01':'2008-12']

plt.plot(y_past, label="Valores pasados")
plt.plot(y_pred, label="Predicción")
plt.plot(y_test, label="Valores futuros")
plt.title('INPC General / Predicción 2008/ Modelo LSTM')

plt.legend(loc=2);

# %%
mse = mean_squared_error(y_test, y_pred)
print('El MSE de la predicción es:', mse)
# Out:
# El MSE de la predicción es: 0.015927255216503417

# %%
#Pronóstico de toda la serie
df1=dataset['1989':'2023']
x_total1 = df1.values
x_total1=sc.transform(x_total1)
X_total1= []
for i in range(time_step,len(x_total1)):
    X_total1.append(x_total1[i-time_step:i,0])
X_total1 = np.array(X_total1)
X_total1 = np.reshape(X_total1, (X_total1.shape[0],X_total1.shape[1],1))
# Out:
# C:\Users\Erik Rosas\anaconda3\envs\ag\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
prediccion3= modelo.predict(X_total1)
prediccion3 = sc.inverse_transform(prediccion3)
prediction3 = np.concatenate(prediccion3, axis=0 ).tolist()
prediction3 = [item for sublist in prediccion3 for item in sublist]
prediction3 = pd.DataFrame(prediction3)
rng = pd.date_range('1989-01-01 00:00:00', periods=408, freq='M')
rng = pd.DataFrame(rng)
prediction3 = pd.merge(rng, prediction3, left_index=True, right_index=True, how='outer')
prediction3.set_index('0_x')
prediction3.columns = ['Date', 'INPC']
prediction3.set_index(['Date'], inplace=True)
# Out:
# 13/13 [==============================] - 0s 4ms/step

# %%
#graficamos el pronóstico de un horizonte de 17 años (2005-2022)
plt.figure(figsize=(10, 5))

item_id = "INPC"
y_past= df1[item_id]['2005':'2022']
y_pred = prediction3[item_id]['2005':'2022']

plt.plot(y_past, label="Valores Reales")
plt.plot(y_pred, label="Predicción")
plt.title('INPC General / Predicción 2005-2022/ Modelo LSTM')

plt.legend();

# %%
histor=pd.DataFrame(hist.history)
